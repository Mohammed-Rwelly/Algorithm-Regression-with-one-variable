# %%
import pandas as pn
import numpy as  np
import matplotlib.pyplot as plt

# %%
data = pn.read_csv('Datasets/app.txt',names=['population','profit'])
data
# Out:
#     population    profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# 5       8.3829  11.88600
# 6       7.4764   4.34830
# 7       8.5781  12.00000
# 8       6.4862   6.59870
# 9       5.0546   3.81660
# 10      5.7107   3.25220
# 11     14.1640  15.50500
# 12      5.7340   3.15510
# 13      8.4084   7.22580
# 14      5.6407   0.71618
# 15      5.3794   3.51290
# 16      6.3654   5.30480
# 17      5.1301   0.56077
# 18      6.4296   3.65180
# 19      7.0708   5.38930
# 20      6.1891   3.13860
# 21     20.2700  21.76700
# 22      5.4901   4.26300
# 23      6.3261   5.18750
# 24      5.5649   3.08250
# 25     18.9450  22.63800
# 26     12.8280  13.50100
# 27     10.9570   7.04670
# 28     13.1760  14.69200
# 29     22.2030  24.14700
# ..         ...       ...
# 67     10.2360   7.77540
# 68      5.4994   1.01730
# 69     20.3410  20.99200
# 70     10.1360   6.67990
# 71      7.3345   4.02590
# ...

# %%
data.plot(kind='scatter',x='population',y='profit',figsize=(5,5))

# %%
data.insert(0,'ones',1)
data
# Out:
#     ones  population    profit
# 0      1      6.1101  17.59200
# 1      1      5.5277   9.13020
# 2      1      8.5186  13.66200
# 3      1      7.0032  11.85400
# 4      1      5.8598   6.82330
# 5      1      8.3829  11.88600
# 6      1      7.4764   4.34830
# 7      1      8.5781  12.00000
# 8      1      6.4862   6.59870
# 9      1      5.0546   3.81660
# 10     1      5.7107   3.25220
# 11     1     14.1640  15.50500
# 12     1      5.7340   3.15510
# 13     1      8.4084   7.22580
# 14     1      5.6407   0.71618
# 15     1      5.3794   3.51290
# 16     1      6.3654   5.30480
# 17     1      5.1301   0.56077
# 18     1      6.4296   3.65180
# 19     1      7.0708   5.38930
# 20     1      6.1891   3.13860
# 21     1     20.2700  21.76700
# 22     1      5.4901   4.26300
# 23     1      6.3261   5.18750
# 24     1      5.5649   3.08250
# 25     1     18.9450  22.63800
# 26     1     12.8280  13.50100
# 27     1     10.9570   7.04670
# 28     1     13.1760  14.69200
# ...

# %%
elpha=0.01
iter1 = 1000
col=data.shape[1]
X=data.iloc[ : ,0 : col-1]
y=data.iloc[: ,col-1:col]
X = np.matrix(X.values)
y = np.matrix(y.values)
theta = np.matrix(np.array([0,0]))

# %%
class Regression(object):
    def __init__(self,X,y,theta,elpha,iter1):
        self.X=X
        self.y=y
        self.theta=theta
        self.elpha=elpha
        self.iter1=iter1
        
    def cost_function(self):
        z=np.power(((X * self.theta.T) - y) , 2)
        c_f= np.sum(z)/(2 *len(X))
        return c_f
    
    def gradient_descent(self):
        temp = np.matrix(np.zeros(theta.shape))
        #print(theta.shape)
        parameters=self.theta.shape[1]
        self.cost=np.zeros(1000)
       # print(cost)
        for i in range(iter1):
            error=(X * self.theta.T) - y
            for j in range(2):
                term=np.multiply(error,X[:,j])
                temp[0,j] =self.theta[0,j]-((elpha /len(X)) *np.sum(term))
            self.theta =temp
            self.cost[i]=self.cost_function()
            print(self.cost[i])
        return self

# %%
Reg = Regression(X , y , theta, elpha ,iter1)
Reg.gradient_descent()
print(Reg.theta)
#print(Reg.cost)
# Out:
# 6.737190464870007
# 5.931593568604956
# 5.901154707081388
# 5.895228586444221
# 5.89009494311733
# 5.885004158443647
# 5.879932480491418
# 5.874879094762575
# 5.869843911806386
# 5.8648268653129305
# 5.859827889932181
# 5.85484692057229
# 5.849883892376588
# 5.844938740722034
# 5.840011401218361
# 5.8351018097072265
# 5.830209902261388
# 5.825335615183863
# 5.820478885007099
# 5.815639648492154
# 5.81081784262787
# 5.806013404630044
# 5.801226271940628
# 5.796456382226899
# 5.7917036733806535
# 5.786968083517396
# 5.782249550975539
# 5.777548014315596
# 5.772863412319381
# 5.768195683989212
# 5.76354476854712
# 5.758910605434049
# 5.754293134309077
# 5.749692295048629
# 5.745108027745684
# 5.740540272709014
# 5.735988970462381
# 5.731454061743792
# 5.726935487504702
# 5.722433188909257
# 5.717947107333528
# 5.713477184364749
# 5.709023361800549
# 5.704585581648199
# 5.700163786123856
# 5.695757917651815
# 5.691367918863752
# 5.68699373259798
# 5.682635301898707
# 5.678292570015292
# ...
